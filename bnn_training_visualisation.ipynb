# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
res_test = np.array([
                    [1,369.886,5028.000222,18.1730],
                    [2,368.672,3641.943050,14.7781],
                    [3,378.887,3332.855439,12.9082],
                    [4,373.023,3073.698498,11.3322],
                    [5,372.605,2923.682312,9.7582],
                    [6,376.094,2800.028252,8.9925],
                    [7,372.910,2682.040542,8.0024],
                    [8,371.098,2575.964118,7.2044],
                    [9,370.898,2539.301387,6.5898],
                    [10,373.559,2471.476416,5.5295],
                    ])

# %%
#Epoch/Time it took (s)/Loss/???Validation energy (%)/Validation distance (%)

epoch    = res_test[:,0]
time     = res_test[:,1]
loss     = res_test[:,2]
val_dist = res_test[:,3]

# %%
plt.plot(epoch, loss)
plt.xlabel('epoch')
plt.ylabel('loss (MSE)')
# Out:
# Text(0, 0.5, 'loss (MSE)')

# %%
plt.plot(epoch, time / 60.)
plt.xlabel('epoch')
plt.ylabel('time, min')
plt.ylim(0, 10)
# Out:
# (0, 10)

# %%
plt.plot(epoch, val_dist)
plt.xlabel('epoch')
plt.ylabel('Validation distance, %')
# Out:
# Text(0, 0.5, 'Validation distance, %')
